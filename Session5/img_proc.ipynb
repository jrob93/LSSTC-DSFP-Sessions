# %%
import numpy as np

from astropy import units as u


# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# !ls
# Out:
# Day1           Day3           Day5           Untitled.ipynb
# Day2           Day4           README.md      img_proc.ipynb

# %%
img='Day4/rings.v3.skycell.1636.006.stk.g.unconv.fits'

from astropy.io import fits

data_g = fits.getdata(img)
data_g
# Out:
# array([[        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,  0.5110123 , -0.0536263 , ...,         nan,
#                 nan,         nan],
#        [        nan, -0.5702367 ,  0.00466442, ...,         nan,
#                 nan,         nan],
#        ...,
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan]], dtype=float32)

# %%
plt.imshow(data_g.data)

# %%
'''colors = []
for filt in 'irg':
    data = fits.getdata(filedict[filt])
    vmin, vmax = np.percentile(data, (1, 99))
    data_norm = (data - vmin) / (vmax - vmin)
    colors.append(data_norm)
    plt.figure()
    plt.imshow(data_norm, origin='lower')
color3 = np.dstack(colors)
color3[color3 < 0.] = 0.
color3[color3 > 1.] = 1.
plt.figure(figsize=(12, 12))
plt.imshow(color3, origin='lower')
factor = 2.
color3_upsample = np.dstack([ndimage.zoom(color3[:, :, i], factor) for i in range(3)])
plt.figure(figsize=(12, 12))
plt.imshow(color3_upsample, origin='lower')'''
